# %% [markdown]
# Importing Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns  
from sklearn.preprocessing import LabelEncoder 
from sklearn.impute import SimpleImputer
import datetime as dt
import warnings  
warnings.filterwarnings('ignore') 
print("All required libraries have been successfully imported!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from sklearn.preprocessing import LabelEncoder
#       6 from sklearn.impute import SimpleImputer
#       7 import datetime as dt
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 24.1.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns  
from sklearn.preprocessing import LabelEncoder 
from sklearn.impute import SimpleImputer
import datetime as dt
import warnings  
warnings.filterwarnings('ignore') 
print("All required libraries have been successfully imported!")
# Out:
# All required libraries have been successfully imported!

# %% [markdown]
# Creating DataFrame

# %%
df = pd.read_csv("sales_5000000.csv")

# %%
df
# Out:
#                                Region           Country        Item Type  \
# 0               Australia and Oceania             Palau  Office Supplies
# 1                              Europe            Poland        Beverages
# 2                       North America            Canada           Cereal
# 3                              Europe           Belarus           Snacks
# 4        Middle East and North Africa              Oman           Cereal
# ...                               ...               ...              ...
# 4999995  Middle East and North Africa              Iraq        Household
# 4999996                        Europe            Monaco             Meat
# 4999997         Australia and Oceania   Solomon Islands          Clothes
# 4999998         Australia and Oceania  Marshall Islands        Cosmetics
# 4999999                        Europe            Greece  Office Supplies
#
#         Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0              Online              H  2020-03-06  517073523  2020-03-26
# 1              Online              L  2014-04-18  380507028  2014-05-26
# 2              Online              M  2019-01-08  504055583  2019-01-31
# 3              Online              C  2018-01-19  954955518  2018-02-27
# 4             Offline              H  2023-04-26  970755660  2023-06-02
# ...               ...            ...         ...        ...         ...
# 4999995        Online              L  2018-03-17  940436398  2018-04-23
# 4999996       Offline              H  2019-11-08  407689177  2019-11-28
# 4999997        Online              C  2024-06-01  727000367  2024-07-18
# 4999998       Offline              L  2024-02-12  714043796  2024-03-22
# 4999999        Online              C  2023-05-11  604805791  2023-06-12
#
#          Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0              2401      651.21     524.96     1563555.21  1260428.96
# 1              9340       47.45      31.79      443183.00   296918.60
# 2               103      205.70     117.11       21187.10    12062.33
# 3              1414      152.58      97.44      215748.12   137780.16
# 4              7027      205.70     117.11     1445453.90   822931.97
# ...             ...         ...        ...            ...         ...
# 4999995        4884      668.27     502.54     3263830.68  2454405.36
# 4999996        3142      421.89     364.69     1325578.38  1145855.98
# 4999997        4419      109.28      35.84      482908.32   158376.96
# 4999998         282      437.20     263.33      123290.40    74259.06
# 4999999        4329      651.21     524.96     2819088.09  2272551.84
#
#          Total Profit
# 0           303126.25
# 1           146264.40
# 2             9124.77
# 3            77967.96
# 4           622521.93
# ...               ...
# 4999995     809425.32
# 4999996     179722.40
# 4999997     324531.36
# 4999998      49031.34
# 4999999     546536.25
#
# [5000000 rows x 14 columns]

# %% [markdown]
# Reducing Data Frame

# %%
df_sampled = df.sample(n=1_000_000, random_state=42)

# %%
df_sampled
# Out:
#                                Region         Country        Item Type  \
# 3577888                        Europe         Andorra           Fruits
# 4993932         Australia and Oceania           Tonga    Personal Care
# 4094900         Australia and Oceania           Tonga           Snacks
# 4420497                        Europe  Czech Republic        Baby Food
# 634465                           Asia           Japan        Beverages
# ...                               ...             ...              ...
# 879073                         Europe      Luxembourg           Snacks
# 461358                         Europe          Greece           Cereal
# 4559407                        Europe          Kosovo           Snacks
# 1450969  Middle East and North Africa          Turkey  Office Supplies
# 4805308                        Europe        Slovakia        Baby Food
#
#         Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 3577888        Online              H  2019-12-21  681978309  2020-01-14
# 4993932        Online              L  2020-01-06  542415893  2020-01-24
# 4094900        Online              C  2018-10-12  492005813  2018-11-18
# 4420497        Online              M  2017-11-06  263193643  2017-12-04
# 634465         Online              L  2015-01-09  632574594  2015-02-01
# ...               ...            ...         ...        ...         ...
# 879073         Online              L  2024-09-03  164502084  2024-09-26
# 461358        Offline              C  2016-10-22  709683597  2016-12-09
# 4559407        Online              M  2017-02-28  896485936  2017-04-15
# 1450969        Online              H  2018-11-09  392313897  2018-12-22
# 4805308        Online              H  2020-08-30  821599090  2020-10-18
#
#          Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 3577888        1391        9.33       6.92       12978.03     9625.72
# 4993932        1771       81.73      56.67      144743.83   100362.57
# 4094900        4308      152.58      97.44      657314.64   419771.52
# 4420497        3702      255.28     159.42      945046.56   590172.84
# 634465         1734       47.45      31.79       82278.30    55123.86
# ...             ...         ...        ...            ...         ...
# 879073         8677      152.58      97.44     1323936.66   845486.88
# 461358            2      205.70     117.11         411.40      234.22
# 4559407        8965      152.58      97.44     1367879.70   873549.60
# 1450969        3255      651.21     524.96     2119688.55  1708744.80
# 4805308        8283      255.28     159.42     2114484.24  1320475.86
#
#          Total Profit
# 3577888       3352.31
# 4993932      44381.26
# 4094900     237543.12
# 4420497     354873.72
# 634465       27154.44
# ...               ...
# 879073      478449.78
# 461358         177.18
# 4559407     494330.10
# 1450969     410943.75
# 4805308     794008.38
#
# [1000000 rows x 14 columns]

# %%
df_sampled.to_csv("reduced_dataset.csv", index=False)

# %% [markdown]
# DATA CLEANING

# %%
null_counts = df_sampled.isnull().sum()  
null_percentage = (null_counts / len(df_sampled)) * 100  
null_df = pd.DataFrame({'Null Count': null_counts, 'Null Percentage': null_percentage})
null_df[null_df['Null Count'] > 0].sort_values(by='Null Percentage', ascending=False)
# Out:
# Empty DataFrame
# Columns: [Null Count, Null Percentage]
# Index: []

# %%
threshold = 40  
null_percentage = (df_sampled.isnull().sum() / len(df_sampled)) * 100  
columns_to_drop = null_percentage[null_percentage > threshold].index.tolist()
print("Columns with high null percentage (> {}%):".format(threshold))
print(columns_to_drop)
# Out:
# Columns with high null percentage (> 40%):
# []

# %%
df_sampled.drop(columns=columns_to_drop, inplace=True)
print("\nUpdated dataset shape:", df_sampled.shape)
# Out:
# Updated dataset shape: (1000000, 14)

# %%
row_threshold = 0.3 * df_sampled.shape[1]
rows_to_drop = df_sampled[df_sampled.isnull().sum(axis=1) > row_threshold]

df_sampled = df_sampled.drop(rows_to_drop.index)

print(f"Removed {len(rows_to_drop)} rows with more than 30% missing values.")
print("Updated dataset shape:", df_sampled.shape)
# Out:
# Removed 0 rows with more than 30% missing values.
# Updated dataset shape: (1000000, 14)

# %%
unwanted_columns = ["Column1", "Column2"] 
df_sampled.drop(columns=unwanted_columns, inplace=True, errors="ignore")

print("Unwanted columns removed.")
print("Final dataset shape:", df_sampled.shape)
# Out:
# Unwanted columns removed.
# Final dataset shape: (1000000, 14)

# %%
df_sampled['Purchase Date'] = pd.to_datetime(df_sampled['Order Date'], errors='coerce')
df_sampled = df_sampled.sort_values(by='Purchase Date', ascending=True)
print("Dataset sorted by Purchase Date.")
# Out:
# Dataset sorted by Purchase Date.

# %%
df_sampled
# Out:
#                                Region                         Country  \
# 4369702                        Europe          Bosnia and Herzegovina
# 1028195            Sub-Saharan Africa                          Guinea
# 640973          Australia and Oceania  Federated States of Micronesia
# 4837943                        Europe                       Lithuania
# 2841590         Australia and Oceania                          Samoa
# ...                               ...                             ...
# 4812427  Middle East and North Africa                         Bahrain
# 3441561                          Asia                       Singapore
# 322106                           Asia                           India
# 3193251                          Asia                       Sri Lanka
# 2461025         Australia and Oceania                           Tonga
#
#                Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 4369702    Personal Care        Online              C  2014-01-01  514631640
# 1028195           Cereal        Online              L  2014-01-01  402343213
# 640973           Clothes        Online              H  2014-01-01  396085298
# 4837943    Personal Care        Online              C  2014-01-01  699614369
# 2841590  Office Supplies        Online              L  2014-01-01  113376605
# ...                  ...           ...            ...         ...        ...
# 4812427  Office Supplies        Online              M  2024-09-10  940800321
# 3441561        Cosmetics       Offline              L  2024-09-10  606217706
# 322106   Office Supplies       Offline              M  2024-09-10  994838893
# 3193251           Fruits        Online              M  2024-09-10  234087598
# 2461025        Household        Online              L  2024-09-10  947058236
#
#           Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 4369702  2014-02-01        9794       81.73      56.67      800463.62
# 1028195  2014-02-14        1153      205.70     117.11      237172.10
# 640973   2014-02-16        9296      109.28      35.84     1015866.88
# 4837943  2014-02-14         294       81.73      56.67       24028.62
# 2841590  2014-01-15        9512      651.21     524.96     6194309.52
# ...             ...         ...         ...        ...            ...
# 4812427  2024-09-24        2576      651.21     524.96     1677516.96
# 3441561  2024-10-05        2145      437.20     263.33      937794.00
# 322106   2024-10-01        3791      651.21     524.96     2468737.11
# 3193251  2024-10-30         577        9.33       6.92        5383.41
# 2461025  2024-09-21        4433      668.27     502.54     2962440.91
#
#          Total Cost  Total Profit Purchase Date
# 4369702   555025.98     245437.64    2014-01-01
# 1028195   135027.83     102144.27    2014-01-01
# 640973    333168.64     682698.24    2014-01-01
# 4837943    16660.98       7367.64    2014-01-01
# 2841590  4993419.52    1200890.00    2014-01-01
# ...             ...           ...           ...
# 4812427  1352296.96     325220.00    2024-09-10
# 3441561   564842.85     372951.15    2024-09-10
# 322106   1990123.36     478613.75    2024-09-10
# 3193251     3992.84       1390.57    2024-09-10
# 2461025  2227759.82     734681.09    2024-09-10
#
# [1000000 rows x 15 columns]

# %%
df_sampled.to_csv("reduced_dataset.csv", index=False)

# %%
df_sampled.drop(columns=['Order Date'], inplace=True, errors='ignore')
print("Order Date column removed.")
print("Updated dataset shape:", df_sampled.shape)
# Out:
# Order Date column removed.
# Updated dataset shape: (1000000, 14)

# %%
df_sampled
# Out:
#                                Region                         Country  \
# 4369702                        Europe          Bosnia and Herzegovina
# 1028195            Sub-Saharan Africa                          Guinea
# 640973          Australia and Oceania  Federated States of Micronesia
# 4837943                        Europe                       Lithuania
# 2841590         Australia and Oceania                          Samoa
# ...                               ...                             ...
# 4812427  Middle East and North Africa                         Bahrain
# 3441561                          Asia                       Singapore
# 322106                           Asia                           India
# 3193251                          Asia                       Sri Lanka
# 2461025         Australia and Oceania                           Tonga
#
#                Item Type Sales Channel Order Priority   Order ID   Ship Date  \
# 4369702    Personal Care        Online              C  514631640  2014-02-01
# 1028195           Cereal        Online              L  402343213  2014-02-14
# 640973           Clothes        Online              H  396085298  2014-02-16
# 4837943    Personal Care        Online              C  699614369  2014-02-14
# 2841590  Office Supplies        Online              L  113376605  2014-01-15
# ...                  ...           ...            ...        ...         ...
# 4812427  Office Supplies        Online              M  940800321  2024-09-24
# 3441561        Cosmetics       Offline              L  606217706  2024-10-05
# 322106   Office Supplies       Offline              M  994838893  2024-10-01
# 3193251           Fruits        Online              M  234087598  2024-10-30
# 2461025        Household        Online              L  947058236  2024-09-21
#
#          Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 4369702        9794       81.73      56.67      800463.62   555025.98
# 1028195        1153      205.70     117.11      237172.10   135027.83
# 640973         9296      109.28      35.84     1015866.88   333168.64
# 4837943         294       81.73      56.67       24028.62    16660.98
# 2841590        9512      651.21     524.96     6194309.52  4993419.52
# ...             ...         ...        ...            ...         ...
# 4812427        2576      651.21     524.96     1677516.96  1352296.96
# 3441561        2145      437.20     263.33      937794.00   564842.85
# 322106         3791      651.21     524.96     2468737.11  1990123.36
# 3193251         577        9.33       6.92        5383.41     3992.84
# 2461025        4433      668.27     502.54     2962440.91  2227759.82
#
#          Total Profit Purchase Date
# 4369702     245437.64    2014-01-01
# 1028195     102144.27    2014-01-01
# 640973      682698.24    2014-01-01
# 4837943       7367.64    2014-01-01
# 2841590    1200890.00    2014-01-01
# ...               ...           ...
# 4812427     325220.00    2024-09-10
# 3441561     372951.15    2024-09-10
# 322106      478613.75    2024-09-10
# 3193251       1390.57    2024-09-10
# 2461025     734681.09    2024-09-10
#
# [1000000 rows x 14 columns]

# %%
df_sampled.drop(columns=['Ship Date'], inplace=True, errors='ignore')
print("Order Date column removed.")
print("Updated dataset shape:", df_sampled.shape)
# Out:
# Order Date column removed.
# Updated dataset shape: (1000000, 13)

# %%
df_sampled
# Out:
#                                Region                         Country  \
# 4369702                        Europe          Bosnia and Herzegovina
# 1028195            Sub-Saharan Africa                          Guinea
# 640973          Australia and Oceania  Federated States of Micronesia
# 4837943                        Europe                       Lithuania
# 2841590         Australia and Oceania                          Samoa
# ...                               ...                             ...
# 4812427  Middle East and North Africa                         Bahrain
# 3441561                          Asia                       Singapore
# 322106                           Asia                           India
# 3193251                          Asia                       Sri Lanka
# 2461025         Australia and Oceania                           Tonga
#
#                Item Type Sales Channel Order Priority   Order ID  Units Sold  \
# 4369702    Personal Care        Online              C  514631640        9794
# 1028195           Cereal        Online              L  402343213        1153
# 640973           Clothes        Online              H  396085298        9296
# 4837943    Personal Care        Online              C  699614369         294
# 2841590  Office Supplies        Online              L  113376605        9512
# ...                  ...           ...            ...        ...         ...
# 4812427  Office Supplies        Online              M  940800321        2576
# 3441561        Cosmetics       Offline              L  606217706        2145
# 322106   Office Supplies       Offline              M  994838893        3791
# 3193251           Fruits        Online              M  234087598         577
# 2461025        Household        Online              L  947058236        4433
#
#          Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  \
# 4369702       81.73      56.67      800463.62   555025.98     245437.64
# 1028195      205.70     117.11      237172.10   135027.83     102144.27
# 640973       109.28      35.84     1015866.88   333168.64     682698.24
# 4837943       81.73      56.67       24028.62    16660.98       7367.64
# 2841590      651.21     524.96     6194309.52  4993419.52    1200890.00
# ...             ...        ...            ...         ...           ...
# 4812427      651.21     524.96     1677516.96  1352296.96     325220.00
# 3441561      437.20     263.33      937794.00   564842.85     372951.15
# 322106       651.21     524.96     2468737.11  1990123.36     478613.75
# 3193251        9.33       6.92        5383.41     3992.84       1390.57
# 2461025      668.27     502.54     2962440.91  2227759.82     734681.09
#
#         Purchase Date
# 4369702    2014-01-01
# 1028195    2014-01-01
# 640973     2014-01-01
# 4837943    2014-01-01
# 2841590    2014-01-01
# ...               ...
# 4812427    2024-09-10
# 3441561    2024-09-10
# 322106     2024-09-10
# 3193251    2024-09-10
# 2461025    2024-09-10
#
# [1000000 rows x 13 columns]

# %%
df_sampled.to_csv("reduced_dataset.csv", index=False)

# %% [markdown]
# Most Engaged Products

# %%
product_engagement = df_sampled['Item Type'].value_counts().reset_index()
product_engagement.columns = ['Item Type', 'Units Sold']

most_engaged_product = product_engagement.iloc[0]
print("Highest Customer Engagement Product:")
print(most_engaged_product)
# Out:
# Highest Customer Engagement Product:
# Item Type     Snacks
# Units Sold     83641
# Name: 0, dtype: object

# %%
product_sales = df_sampled.groupby('Item Type')['Total Revenue'].sum().reset_index()
product_sales = product_sales.sort_values(by='Total Revenue', ascending=False)

top_product = product_sales.iloc[0]
print("Highest Revenue Generating Product:")
print(top_product)
# Out:
# Highest Revenue Generating Product:
# Item Type                  Household
# Total Revenue    277496609482.690002
# Name: 6, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.barplot(x=product_engagement['Item Type'][:10], y=product_engagement['Units Sold'][:10], palette="viridis")
plt.xticks(rotation=45)
plt.xlabel("Item Type")
plt.ylabel("Units Sold")
plt.title("Top 10 Most Engaged Products")
plt.show()

# %% [markdown]
# Most Units Sold and its Profit

# %%
product_sales_count = df_sampled['Item Type'].value_counts().reset_index()
product_sales_count.columns = ['Item Type', 'Units Sold']
print(product_sales_count.head(10))
# Out:
#          Item Type  Units Sold
# 0           Snacks       83641
# 1           Fruits       83565
# 2       Vegetables       83532
# 3        Baby Food       83443
# 4           Cereal       83420
# 5             Meat       83410
# 6        Beverages       83372
# 7          Clothes       83230
# 8  Office Supplies       83173
# 9        Cosmetics       83170

# %%
product_sales_revenue = df_sampled.groupby('Item Type')['Total Profit'].sum().reset_index()
product_sales_revenue = product_sales_revenue.sort_values(by='Total Profit', ascending=False)

print(product_sales_revenue.head(10))
# Out:
#           Item Type  Total Profit
# 4         Cosmetics  7.208481e+10
# 6         Household  6.881876e+10
# 8   Office Supplies  5.252351e+10
# 0         Baby Food  4.005826e+10
# 2            Cereal  3.686232e+10
# 3           Clothes  3.051282e+10
# 11       Vegetables  2.631973e+10
# 7              Meat  2.390524e+10
# 10           Snacks  2.304180e+10
# 9     Personal Care  1.040127e+10

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.barplot(x=product_sales_revenue['Item Type'][:10], y=product_sales_revenue['Total Profit'][:10], palette="coolwarm")
plt.xticks(rotation=45)
plt.xlabel("Item Type")
plt.ylabel("Total Profit")
plt.title("Top 10 Profit-Generating Products")
plt.show()

# %% [markdown]
# Yearly Sales

# %%
df_sampled['Purchase Date'] = pd.to_datetime(df_sampled['Purchase Date'], errors='coerce')
df_sampled['Year'] = df_sampled['Purchase Date'].dt.year

# %%
df_sampled['Year']
# Out:
# 4369702    2014
# 1028195    2014
# 640973     2014
# 4837943    2014
# 2841590    2014
#            ...
# 4812427    2024
# 3441561    2024
# 322106     2024
# 3193251    2024
# 2461025    2024
# Name: Year, Length: 1000000, dtype: int32

# %%
yearly_sales = df_sampled.groupby('Year')['Total Profit'].sum().reset_index()
yearly_sales = yearly_sales.sort_values(by='Year', ascending=True)

print("Year-wise Sales Classification:")
print(yearly_sales)
# Out:
# Year-wise Sales Classification:
#     Year  Total Profit
# 0   2014  3.666861e+10
# 1   2015  3.651901e+10
# 2   2016  3.702472e+10
# 3   2017  3.658070e+10
# 4   2018  3.641282e+10
# 5   2019  3.699914e+10
# 6   2020  3.639818e+10
# 7   2021  3.650900e+10
# 8   2022  3.674266e+10
# 9   2023  3.677060e+10
# 10  2024  2.543752e+10

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=yearly_sales, x='Year', y='Total Profit', marker='o', color='b')
plt.xlabel("Year")
plt.ylabel("Total Profit")
plt.title("Year-wise Sales Classification")
plt.grid(True)
plt.show()

# %% [markdown]
# Order Priority

# %%
priority_sales = df_sampled.groupby('Order Priority')['Total Profit'].sum().reset_index()
priority_sales = priority_sales.sort_values(by='Total Profit', ascending=False)

print("Total Sales by Order Priority:")
print(priority_sales)
# Out:
# Total Sales by Order Priority:
#   Order Priority  Total Profit
# 0              C  9.816042e+10
# 3              M  9.805954e+10
# 1              H  9.796677e+10
# 2              L  9.787622e+10

# %%
priority_orders = df_sampled['Order Priority'].value_counts().reset_index()
priority_orders.columns = ['Order Priority', 'Units Sold']

print("Order Volume by Priority:")
print(priority_orders)
# Out:
# Order Volume by Priority:
#   Order Priority  Units Sold
# 0              M      250489
# 1              C      250202
# 2              L      249732
# 3              H      249577

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.barplot(x=priority_sales['Order Priority'], y=priority_orders['Units Sold'], palette="coolwarm")
plt.xlabel("Order Priority")
plt.ylabel("Units Sold")
plt.title("Sales Distribution by Order Priorit")
plt.show()

# %%
df_sampled['PAT Income'] = df_sampled['Total Revenue'] - df_sampled['Total Cost']

# %%
df_sampled['PAT Income']
# Out:
# 4369702     245437.64
# 1028195     102144.27
# 640973      682698.24
# 4837943       7367.64
# 2841590    1200890.00
#               ...
# 4812427     325220.00
# 3441561     372951.15
# 322106      478613.75
# 3193251       1390.57
# 2461025     734681.09
# Name: PAT Income, Length: 1000000, dtype: float64

# %% [markdown]
# Month Wise Classification

# %%
df_sampled['Purchase Date'] = pd.to_datetime(df_sampled['Purchase Date'], errors='coerce')
df_sampled['Month'] = df_sampled['Purchase Date'].dt.month_name()

# %%
monthly_sales = df_sampled.groupby('Month')['Total Profit'].sum().reset_index()
monthly_sales = monthly_sales.sort_values(by='Total Profit', ascending=False)

print("Month-wise Sales Classification:")
print(monthly_sales)
# Out:
# Month-wise Sales Classification:
#         Month  Total Profit
# 5        July  3.443416e+10
# 8         May  3.427095e+10
# 4     January  3.423547e+10
# 1      August  3.402837e+10
# 7       March  3.395267e+10
# 0       April  3.320233e+10
# 6        June  3.305524e+10
# 2    December  3.117489e+10
# 3    February  3.111800e+10
# 10    October  3.109965e+10
# 11  September  3.108691e+10
# 9    November  3.040432e+10

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.barplot(x=monthly_sales['Month'], y=monthly_sales['Total Profit'], palette="coolwarm")
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.title("Month-wise Sales Classification")
plt.show()

# %%
df_sampled.to_csv("reduced_dataset.csv", index=False)

# %% [markdown]
# Thank You
